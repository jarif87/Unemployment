# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=pd.read_csv("/kaggle/input/umemployee/Unemployment in India.csv")
df2=pd.read_csv("/kaggle/input/umemployee/Unemployment_Rate_upto_11_2020.csv")

# %%
df1.head()
# Out:
#            Region         Date  Frequency  unemployment_rate  \
# 0  Andhra Pradesh   31-05-2019    Monthly               3.65
# 1  Andhra Pradesh   30-06-2019    Monthly               3.05
# 2  Andhra Pradesh   31-07-2019    Monthly               3.75
# 3  Andhra Pradesh   31-08-2019    Monthly               3.32
# 4  Andhra Pradesh   30-09-2019    Monthly               5.17
#
#    estimated_employee  Labour_Participation_ Rate   Area
# 0          11999139.0                       43.24  Rural
# 1          11755881.0                       42.05  Rural
# 2          12086707.0                       43.50  Rural
# 3          12285693.0                       43.97  Rural
# 4          12256762.0                       44.68  Rural

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Region                      740 non-null    object
#  1    Date                       740 non-null    object
#  2    Frequency                  740 non-null    object
#  3   unemployment_rate           740 non-null    float64
#  4   estimated_employee          740 non-null    float64
#  5   Labour_Participation_ Rate  740 non-null    float64
#  6   Area                        740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
df1.isnull().sum()
# Out:
# Region                        14
#  Date                         14
#  Frequency                    14
# unemployment_rate             14
# estimated_employee            14
# Labour_Participation_ Rate    14
# Area                          14
# dtype: int64

# %%
df1.shape
# Out:
# (754, 7)

# %%
df1=df1.dropna()

# %%
df1.isnull().sum()
# Out:
# Region                        0
#  Date                         0
#  Frequency                    0
# unemployment_rate             0
# estimated_employee            0
# Labour_Participation_ Rate    0
# Area                          0
# dtype: int64

# %%
df1.describe()
# Out:
#        unemployment_rate  estimated_employee  Labour_Participation_ Rate
# count         740.000000        7.400000e+02                  740.000000
# mean           11.787946        7.204460e+06                   42.630122
# std            10.721298        8.087988e+06                    8.111094
# min             0.000000        4.942000e+04                   13.330000
# 25%             4.657500        1.190404e+06                   38.062500
# 50%             8.350000        4.744178e+06                   41.160000
# 75%            15.887500        1.127549e+07                   45.505000
# max            76.740000        4.577751e+07                   72.570000

# %%
plt.figure(figsize=(15,10))
sns.countplot(y="Region",data=df1)
plt.show()

# %% [markdown]
# # avg,high,lowest unemployment rate

# %%
avg_unemployment_rate=df1.groupby('Region')['unemployment_rate'].mean()
state_with_highest_unemployment=avg_unemployment_rate.idxmax()
high_unemployment_rate=avg_unemployment_rate.max()
state_with_lowest_unemployment=avg_unemployment_rate.idxmin()
low_unemploy_rate=avg_unemployment_rate.min()
print(f"state  with  high employment : {state_with_highest_unemployment}")
print(f"high employment rate : {high_unemployment_rate}")
print(f"state  with  low employment : {state_with_lowest_unemployment}")
print(f"low employment rate : {low_unemploy_rate}")
# Out:
# state  with  high employment : Tripura
# high employment rate : 28.350357142857142
# state  with  low employment : Meghalaya
# low employment rate : 4.7988888888888885

# %%
regions = avg_unemployment_rate.index
avg_rates = avg_unemployment_rate.values

plt.figure(figsize=(10, 6))
plt.bar(regions, avg_rates, color='skyblue')
plt.xlabel('Region')
plt.ylabel('Average Unemployment Rate')
plt.title('Average Unemployment Rate by Region')
plt.xticks(rotation=90)  
plt.tight_layout()  
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='unemployment_rate', data=df1,palette="Set1")
plt.title("Unemployment Rate Distribution by Region")
plt.xlabel("State")
plt.ylabel("Estimated Unemployment Rate")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='Labour_Participation_ Rate', data=df1,palette="hsv")
plt.title("Labour_Participation_ Rate")
plt.xlabel("Region")
plt.ylabel("Labour_Participation_ Rate")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='estimated_employee', data=df1,palette="brg")
plt.title("estimated_employee")
plt.xlabel("Region")
plt.ylabel("estimated_employee")
plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(data=df1, x="unemployment_rate", kde=True,color="navy")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df1, x="estimated_employee", kde=True,color="brown")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df1, x="Labour_Participation_ Rate", kde=True,color="darkorange")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Unemployment Rate vs. Labor Participation Rate

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(data=df1, x="unemployment_rate", y="Labour_Participation_ Rate", hue="Region")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x=df1["estimated_employee"])
plt.show()

# %%
pair=df1[["unemployment_rate","estimated_employee","Labour_Participation_ Rate"]]
sns.pairplot(pair,markers="*",palette="winter")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1609: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %%
df1["Area"].value_counts()
# Out:
# Area
# Urban    381
# Rural    359
# Name: count, dtype: int64

# %%
sns.countplot(x="Area",data=df1)
plt.show()

# %% [markdown]
# # Unemployment in India (2020)

# %%
df2.head()
# Out:
#            Region    date_time  Frequency  unemployee_rate  \
# 0  Andhra Pradesh   31-01-2020          M             5.48
# 1  Andhra Pradesh   29-02-2020          M             5.83
# 2  Andhra Pradesh   31-03-2020          M             5.79
# 3  Andhra Pradesh   30-04-2020          M            20.51
# 4  Andhra Pradesh   31-05-2020          M            17.43
#
#    estimated_employee  labour_rate Region.1  longitude  latitude
# 0            16635535        41.02    South    15.9129     79.74
# 1            16545652        40.90    South    15.9129     79.74
# 2            15881197        39.18    South    15.9129     79.74
# 3            11336911        33.10    South    15.9129     79.74
# 4            12988845        36.46    South    15.9129     79.74

# %%
df2.shape
# Out:
# (267, 9)

# %%
df2.isnull().sum()
# Out:
# Region                0
# date_time             0
#  Frequency            0
# unemployee_rate       0
# estimated_employee    0
# labour_rate           0
# Region.1              0
# longitude             0
# latitude              0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              267 non-null    object
#  1   date_time           267 non-null    object
#  2    Frequency          267 non-null    object
#  3   unemployee_rate     267 non-null    float64
#  4   estimated_employee  267 non-null    int64
#  5   labour_rate         267 non-null    float64
#  6   Region.1            267 non-null    object
#  7   longitude           267 non-null    float64
#  8   latitude            267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df2.describe()
# Out:
#        unemployee_rate  estimated_employee  labour_rate   longitude  \
# count       267.000000        2.670000e+02   267.000000  267.000000
# mean         12.236929        1.396211e+07    41.681573   22.826048
# std          10.803283        1.336632e+07     7.845419    6.270731
# min           0.500000        1.175420e+05    16.770000   10.850500
# 25%           4.845000        2.838930e+06    37.265000   18.112400
# 50%           9.650000        9.732417e+06    40.390000   23.610200
# 75%          16.755000        2.187869e+07    44.055000   27.278400
# max          75.850000        5.943376e+07    69.690000   33.778200
#
#          latitude
# count  267.000000
# mean    80.532425
# std      5.831738
# min     71.192400
# 25%     76.085600
# 50%     79.019300
# 75%     85.279900
# max     92.937600

# %%
plt.figure(figsize=(10,7))
sns.countplot(y="Region",data=df2)
plt.show()

# %%
import plotly.express as px
fig = px.bar(df2, x="Region", y="estimated_employee", title="estimated_employee", 
             animation_frame='date_time',template='plotly',color="Region")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d7eeed84-5869-4991-b1a5-88bdcb772cdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7eeed84-5869-4991-b1a5-88bdcb772cdb")) {                    Plotly.newPlot(                        "d7eeed84-5869-4991-b1a5-88bdcb772cdb",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[16635535],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam"],"xaxis":"x","y":[13051904],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Bihar"],"xaxis":"x","y":[26397671],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh"],"xaxis":"x","y":[8552172],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi"],"xaxis":"x","y":[5805284],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Goa"],"xaxis":"x","y":[416750],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Gujarat"],"xaxis":"x","y":[24126346],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Haryana"],"xaxis":"x","y":[7693231],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgrou ...

# %%
fig = px.bar(df2, x="Region", y="unemployee_rate", title="unemployee rate 2020", 
             animation_frame='date_time',template='plotly',color="Region")
fig.show()
# Out:
# <div>                            <div id="3d0a4484-5bff-4b37-af39-9e6885fba34b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d0a4484-5bff-4b37-af39-9e6885fba34b")) {                    Plotly.newPlot(                        "3d0a4484-5bff-4b37-af39-9e6885fba34b",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam"],"xaxis":"x","y":[4.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Bihar"],"xaxis":"x","y":[10.61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh"],"xaxis":"x","y":[9.65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi"],"xaxis":"x","y":[22.23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Goa"],"xaxis":"x","y":[8.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Gujarat"],"xaxis":"x","y":[5.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Haryana"],"xaxis":"x","y":[20.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF"," ...

# %%
fig = px.bar(df2, x="Region", y="labour_rate", title="labour_rate 2020", 
             animation_frame='date_time',template='plotly',color="Region")
fig.show()
# Out:
# <div>                            <div id="79fcacb5-cbd7-4307-8af8-1ab83f9718c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79fcacb5-cbd7-4307-8af8-1ab83f9718c4")) {                    Plotly.newPlot(                        "79fcacb5-cbd7-4307-8af8-1ab83f9718c4",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[41.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"textposition":"auto","x":["Assam"],"xaxis":"x","y":[52.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"textposition":"auto","x":["Bihar"],"xaxis":"x","y":[37.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh"],"xaxis":"x","y":[43.08],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi"],"xaxis":"x","y":[47.79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"textposition":"auto","x":["Goa"],"xaxis":"x","y":[35.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"textposition":"auto","x":["Gujarat"],"xaxis":"x","y":[48.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"textposition":"auto","x":["Haryana"],"xaxis":"x","y":[43.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":" ...

# %% [markdown]
# # Time Series Line Plot for Unemployment Rate by Region

# %%
fig = px.line(df2, x='date_time', y="unemployee_rate", color='Region',
                    title='Unemployment Rate Over Time', template='plotly')
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="9a94d68b-2cd3-4377-9799-f245ba26e933" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a94d68b-2cd3-4377-9799-f245ba26e933")) {                    Plotly.newPlot(                        "9a94d68b-2cd3-4377-9799-f245ba26e933",                        [{"hovertemplate":"Region=Andhra Pradesh\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[5.48,5.83,5.79,20.51,17.43,3.31,8.34,6.96,6.4,6.59],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Assam","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[4.66,4.41,4.77,11.06,9.55,0.6,3.77,5.53,1.19,3.02],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Bihar\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bihar","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[10.61,10.29,15.43,46.64,45.96,17.82,12.79,13.44,11.91,9.82],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Chhattisgarh\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[9.65,8.38,7.54,3.41,10.5,14.23,10.27,5.63,1.96,6.62],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Delhi\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Delhi","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[22.23,14.84,17.04,16.68,42.27,18.19,20.3,13.79,12.53,6.27],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Goa\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Goa","orientation":"v","showlegend":true,"x":[" 31-01-2020"," 29-02-2020"," 31-03-2020"," 30-04-2020"," 31-05-2020"," 30-06-2020"," 31-07-2020"," 31-08-2020"," 30-09-2020"," 31-10-2020"],"xaxis":"x","y":[8.89,2.81,5.25,13.31,21.25,9.96,17.07,16.21,15.38,11.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Gujarat\u003cbr\u003edate_time=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","line":{"color":"#F ...

# %% [markdown]
# # Bar Plot for Average Unemployment Rate by Region

# %%
avg_unemployment = df2.groupby('Region')['unemployee_rate'].mean().reset_index()

bar_plot = px.bar(avg_unemployment, x='Region', y='unemployee_rate',
                   title='Average Unemployment Rate by Region', template='plotly')
bar_plot.show()
# Out:
# <div>                            <div id="673264a2-1efa-45d8-825e-8605808813c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("673264a2-1efa-45d8-825e-8605808813c3")) {                    Plotly.newPlot(                        "673264a2-1efa-45d8-825e-8605808813c3",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andhra Pradesh","Assam","Bihar","Chhattisgarh","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Meghalaya","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[8.664,4.856,19.471,7.819,18.414,12.167,6.3759999999999994,27.476999999999997,16.065,16.477777777777778,19.538999999999998,7.667999999999999,9.434000000000001,6.854000000000001,7.979000000000001,3.8659999999999997,6.462000000000001,17.942,11.981,15.868,9.7925,12.187,6.833,25.055,9.737,11.156,10.192],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":"" ...

# %% [markdown]
# # Bar Plot for Average labour Rate by Region

# %%
avg_unemployment = df2.groupby('Region')['labour_rate'].mean().reset_index()

bar_plot = px.bar(avg_unemployment, x='Region', y='labour_rate',
                   title='Average labour Rate by Region', template='plotly')
bar_plot.show()
# Out:
# <div>                            <div id="8d6b42c7-b3e1-4609-80e4-e2952c863745" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d6b42c7-b3e1-4609-80e4-e2952c863745")) {                    Plotly.newPlot(                        "8d6b42c7-b3e1-4609-80e4-e2952c863745",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Andhra Pradesh","Assam","Bihar","Chhattisgarh","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu & Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Meghalaya","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"xaxis":"x","y":[38.962,43.498000000000005,37.173,41.161,35.857,39.242000000000004,45.489999999999995,42.1,40.251999999999995,37.894444444444446,40.356,42.0,33.382,38.926,41.465999999999994,59.859,37.748000000000005,35.918,39.979,40.591,45.75625,37.382999999999996,54.972,57.848,37.608,35.259,45.158],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fil ...

# %% [markdown]
# # Scatter Plot for Unemployment Rate vs. Estimated Employed

# %%
fig = px.scatter(df2, x='estimated_employee', y='unemployee_rate',
                          color='Region', title='Unemployment Rate vs. Estimated Employed',animation_frame="date_time")
fig.show()
# Out:
# <div>                            <div id="984311b1-253c-41d9-8faa-aef9b9a54402" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("984311b1-253c-41d9-8faa-aef9b9a54402")) {                    Plotly.newPlot(                        "984311b1-253c-41d9-8faa-aef9b9a54402",                        [{"hovertemplate":"Region=Andhra Pradesh\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[16635535],"xaxis":"x","y":[5.48],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"x":[13051904],"xaxis":"x","y":[4.66],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Bihar\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"x":[26397671],"xaxis":"x","y":[10.61],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Chhattisgarh\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":[8552172],"xaxis":"x","y":[9.65],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Delhi\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"x":[5805284],"xaxis":"x","y":[22.23],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Goa\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"x":[416750],"xaxis":"x","y":[8.89],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Gujarat\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"x":[24126346],"xaxis":"x","y":[5.54],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Haryana\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Haryana","orientation":"v","showlegend":true,"x":[7693231],"xaxis":"x","y":[20.34],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Himachal Pradesh\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003eunemployee_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Himachal Pradesh","orientation":"v","showlegend":true,"x":[ ...

# %%
fig = px.scatter(df2, x='Region.1', y='labour_rate',
                          color='Region', title='Region.1 vs labour rate',animation_frame="date_time")
fig.show()
# Out:
# <div>                            <div id="5d867440-3327-4f7c-97ed-a866e8f32f60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d867440-3327-4f7c-97ed-a866e8f32f60")) {                    Plotly.newPlot(                        "5d867440-3327-4f7c-97ed-a866e8f32f60",                        [{"hovertemplate":"Region=Andhra Pradesh\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["South"],"xaxis":"x","y":[41.02],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Assam\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Assam","orientation":"v","showlegend":true,"x":["Northeast"],"xaxis":"x","y":[52.98],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Bihar\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Bihar","orientation":"v","showlegend":true,"x":["East"],"xaxis":"x","y":[37.72],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Chhattisgarh\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"Chhattisgarh","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[43.08],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Delhi\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Delhi","orientation":"v","showlegend":true,"x":["North"],"xaxis":"x","y":[47.79],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Goa\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Goa","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[35.73],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Gujarat\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Gujarat","orientation":"v","showlegend":true,"x":["West"],"xaxis":"x","y":[48.49],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Haryana\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Haryana","orientation":"v","showlegend":true,"x":["North"],"xaxis":"x","y":[43.36],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Himachal Pradesh\u003cbr\u003edate_time= 31-01-2020\u003cbr\u003eRegion.1=%{x}\u003cbr\u003elabour_rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Himachal Pradesh","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"Himachal Pradesh","orientation":"v","showlegend":true,"x":["North"],"xaxis":"x","y":[45.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Jammu & Kashmir\u003cbr\u003edate_tim ...

# %% [markdown]
# # Histogram for Estimated Labour Participation Rate

# %%
fig = px.histogram(df2, x='labour_rate', color='Region',
                         title='Distribution of Labour Participation Rate by Region', template='plotly')
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="fb718ba4-1406-4fcf-b414-c49fa77400c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb718ba4-1406-4fcf-b414-c49fa77400c8")) {                    Plotly.newPlot(                        "fb718ba4-1406-4fcf-b414-c49fa77400c8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Andhra Pradesh\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[41.02,40.9,39.18,33.1,36.46,47.41,38.91,37.83,37.47,37.34],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Assam\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"x":[52.98,40.77,46.73,29.55,48.26,35.07,40.88,39.52,54.38,46.84],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Bihar\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"x":[37.72,37.35,38.69,38.17,38.16,36.86,36.14,34.59,38.35,35.7],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Chhattisgarh\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"x":[43.08,45.58,45.59,35.58,35.23,38.48,43.14,42.97,41.14,40.82],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Delhi\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"x":[47.79,43.92,42.65,23.8,28.91,34.17,33.97,35.41,35.59,32.36],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Goa\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"x":[35.73,38.38,33.88,44.97,37.36,42.21,42.94,43.76,38.89,34.3],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Gujarat\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"x":[48.49,50.11,47.75,35.5,38.23,45.96,46.41,43.55,48.41,50.49],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Haryana\u003cbr\u003elabour_rate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Haryana","offsetgroup":"Haryana","orientation":"v","showlegend":true,"x":[43.36,44.21,39.63,44.38,40.39,42.14,39.77,47.32,39.2,40.6],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bin ...

# %% [markdown]
# # Histogram for estimated_employee Rate

# %%
fig = px.histogram(df2, x='estimated_employee', color='Region',
                         title='Distribution of Labour Participation Rate by Region', template='plotly')
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="03248532-7cd2-46d7-9a66-ee912365ea11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03248532-7cd2-46d7-9a66-ee912365ea11")) {                    Plotly.newPlot(                        "03248532-7cd2-46d7-9a66-ee912365ea11",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Andhra Pradesh\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":[16635535,16545652,15881197,11336911,12988845,19805400,15431615,15251776,15220312,15157557],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Assam\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Assam","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Assam","offsetgroup":"Assam","orientation":"v","showlegend":true,"x":[13051904,10088268,11542888,6830817,11367897,9095944,10286757,9781310,14107641,11949329],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Bihar\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bihar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bihar","offsetgroup":"Bihar","orientation":"v","showlegend":true,"x":[26397671,26281655,25717519,16046236,16280203,23963933,24989370,23795534,26902907,25693252],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Chhattisgarh\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chhattisgarh","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"x":[8552172,9195114,9302317,7600448,6991217,7332807,8620294,9050422,9021854,8546847],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Delhi\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"x":[5805284,5856307,5553805,3119274,2632404,4418914,4291053,4850107,4958373,4842698],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Goa\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Goa","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Goa","offsetgroup":"Goa","orientation":"v","showlegend":true,"x":[416750,478068,411761,500614,378244,489111,458876,473016,425004,392304],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Gujarat\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gujarat","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Gujarat","offsetgroup":"Gujarat","orientation":"v","showlegend":true,"x":[24126346,24757795,23566641,15288878,17836936,23657055,24276120,22817232,25010199,25970259],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Region=Haryana\u003cbr\u003eestimated_employee=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haryana","marker":{"color":"#B6E880","pattern" ...

# %%
df2["Region.1"].value_counts()
# Out:
# Region.1
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: count, dtype: int64

# %%
sns.countplot(y="Region.1",data=df2)
plt.show()
